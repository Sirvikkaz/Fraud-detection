# %% [markdown]
# ### EDA and model building notebook

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../data/creditcard.csv")

# %%
df.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.shape[0]
# Out:
# 284807

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# ##### Checking if any column has less than missing rows

# %%
columns_list  = df.columns.to_list()

# %%
df['Time'].isna().sum().item()
# Out:
# 0

# %%
missing_dict = {}
for col in columns_list:
    x = df[col].isna().sum().item()
    if x>0:
        missing_dict[col] = x
    else:
        pass

# %%
missing_dict
# Out:
# {}

# %%
df[df.duplicated()]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 282987  171288.0  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627.0 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
# ...

# %%
df = df.drop_duplicates()

# %%
df.duplicated().astype(int).sum().item()
# Out:
# 0

# %% [markdown]
# ##### Exploring the fraudulent and non fraudulent count

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
df["Class"].value_counts().plot(kind="bar")

plt.xticks([0, 1], ["Non-Fraud", "Fraud"])
plt.xlabel("Class")
plt.ylabel("Count")
plt.title("Distribution of Fraud vs Non-Fraud Transactions")
plt.show()

# %%
df['Class'].value_counts().plot( kind='pie',
    autopct="%1.2f%%",
    labels=["Non-Fraud", "Fraud"])
# Out:
# <Axes: >

# %% [markdown]
# ##### fraud percentage

# %%
df["Class"].value_counts(normalize=True) * 100
# Out:
# Class
# 0    99.83329
# 1     0.16671
# Name: proportion, dtype: float64

# %% [markdown]
# ##### Amount analysis

# %%
#maximum amount in transaction
df['Amount'].max().item()
# Out:
# 25691.16

# %%
#minimum amount in transaction
df['Amount'].min().item()
# Out:
# 0.0

# %%
df[df['Amount']==0]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 383        282.0 -0.356466  0.725418  1.971749  0.831343  0.369681 -0.107776
# 514        380.0 -1.299837  0.881817  1.452842 -1.293698 -0.025105 -1.170103
# 534        403.0  1.237413  0.512365  0.687746  1.693872 -0.236323 -0.650232
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 575        430.0 -1.860258 -0.629859  0.966570  0.844632  0.759983 -1.481173
# ...          ...       ...       ...       ...       ...       ...       ...
# 283719  171817.0 -0.750414  0.904175  0.996461  0.427284  1.720336  0.929256
# 283782  171870.0  2.083677 -0.065811 -1.442870  0.135416  0.043035 -1.306975
# 283949  172027.0  2.132569 -0.057836 -1.724522 -0.030326  0.412146 -0.903088
# 284085  172140.0 -2.210521 -1.039425  0.189704 -1.291932  3.742120 -1.665061
# 284770  172759.0 -0.822731  1.270140 -0.138566  0.479620  1.242101  0.795218
#
# ...

# %%
df['Amount'].describe()
# Out:
# count    283726.000000
# mean         88.472687
# std         250.399437
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.510000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
df.groupby("Class")["Amount"].describe()
# Out:
#           count        mean         std  min   25%    50%     75%       max
# Class
# 0      283253.0   88.413575  250.379023  0.0  5.67  22.00   77.46  25691.16
# 1         473.0  123.871860  260.211041  0.0  1.00   9.82  105.89   2125.87

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Amount"], bins=50)
plt.xlabel("Transaction Amount")
plt.ylabel("Frequency")
plt.title("Distribution of Transaction Amount")
plt.show()

# %%
# we can see that this data is heavily skewed towards the left.

# %%
df.boxplot(column="Amount", by="Class")
plt.suptitle("")
plt.title("Transaction Amount by Class")
plt.show()

# %% [markdown]
# ##### Time analysis

# %%
df['Time'].describe()
# Out:
# count    283726.000000
# mean      94811.077600
# std       47481.047891
# min           0.000000
# 25%       54204.750000
# 50%       84692.500000
# 75%      139298.000000
# max      172792.000000
# Name: Time, dtype: float64

# %%
df['Time'].plot(
    kind='hist',
    bins=50
)
# Out:
# <Axes: ylabel='Frequency'>

# %%
class_fraud = df[df['Class']==1]

# %%
class_fraud['Time'].count()
# Out:
# np.int64(473)

# %%
class_fraud.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
class_fraud['Time'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
(class_fraud['Time'].max() - class_fraud['Time'].min()).item()
# Out:
# 169942.0

# %%
non_fraud = df[df['Class']==0]

# %%
non_fraud.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
non_fraud['Time'].describe()
# Out:
# count    283253.000000
# mean      94835.058093
# std       47475.550607
# min           0.000000
# 25%       54233.000000
# 50%       84711.000000
# 75%      139308.000000
# max      172792.000000
# Name: Time, dtype: float64

# %%
#Difference in time
(non_fraud['Time'].max()- non_fraud['Time'].min()).item()
# Out:
# 172792.0

# %%
non_fraud['Time'].plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot(column="Time", by="Class")
plt.suptitle("")
plt.ylabel("Time")
plt.title("boxplot of fraud and non fraud time distribution")
plt.show()

# %% [markdown]
# ##### Feature correlation with class

# %%
corr = df.corr(numeric_only=True)['Class'].sort_values()

# %%
corr
# Out:
# V17      -0.313498
# V14      -0.293375
# V12      -0.250711
# V10      -0.206971
# V16      -0.187186
# V3       -0.182322
# V7       -0.172347
# V18      -0.105340
# V1       -0.094486
# V9       -0.094021
# V5       -0.087812
# V6       -0.043915
# Time     -0.012359
# V24      -0.007210
# V23      -0.006333
# V13      -0.003897
# V15      -0.003300
# V25       0.003202
# V26       0.004265
# V22       0.004887
# Amount    0.005777
# V28       0.009682
# V20       0.021486
# V27       0.021892
# V21       0.026357
# V8        0.033068
# V19       0.033631
# V2        0.084624
# V4        0.129326
# V11       0.149067
# Class     1.000000
# Name: Class, dtype: float64

# %%
corr = df.corr(numeric_only=True)["Class"].sort_values()
plt.figure(figsize=(8,6))
corr.plot(kind="barh")
plt.title("Correlation of features with fraud class")
plt.show()

# %% [markdown]
# ##### Data preprocessing

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
X = df.copy()

# %%
del X['Class']

# %%
X.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V20       V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %%
df.head(1)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
#
# [1 rows x 31 columns]

# %%
Y = df['Class']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# %%
Y_test.head(1)
# Out:
# 104697    0
# Name: Class, dtype: int64

# %%
X_train.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 79119    57873.0 -1.353894 -1.081034  1.787587 -1.803254 -0.235223  2.177295
# 265736  162025.0 -0.059936  0.582525 -1.369698 -1.100370  3.707608  3.396709
# 42801    41251.0 -0.362164  0.715165  1.783253  0.230848 -0.240500 -0.508633
# 172689  121201.0 -0.370982  0.446004 -0.732017 -1.088288  1.799175 -1.117223
# 179949  124306.0  0.695644  0.177228  0.481414 -0.338853 -0.122807  0.074431
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 79119   1.014795  0.549627  0.629906  ...  0.420106  0.182520  0.367052
# 265736  1.218666  0.541196 -0.507983  ... -0.103629  0.069615  0.311566
# 42801   0.589763 -0.013746 -0.048097  ... -0.036132 -0.212595 -0.515372
# 172689  1.502962 -0.553382 -0.240976  ... -0.233555  0.263039  0.937860
# 179949 -0.509006 -0.775719  0.982836  ... -0.275961  0.956704  0.468104
#
# ...

# %% [markdown]
# ##### Chain of thought for scailing, since v1 to v28 are pca components, they have already been scaled, what we have to scale is amount and time features alone

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_amount_scaled = scaler.fit_transform(X_train['Amount'].to_frame())
test_amount_scaled = scaler.transform(X_test['Amount'].to_frame())
train_time_scaled = scaler.fit_transform(X_train['Time'].to_frame())
test_time_scaled = scaler.transform(X_test['Time'].to_frame())

# %%
X_train['Amount'] = train_amount_scaled
X_test['Amount'] = test_amount_scaled
X_train['Time'] = train_time_scaled
X_test['Time'] = test_time_scaled

# %%
X_train['Amount']
# Out:
# 79119     0.909212
# 265736   -0.218631
# 42801    -0.271442
# 172689   -0.325679
# 179949   -0.311060
#             ...
# 120348    3.014509
# 260136   -0.347112
# 132427   -0.332810
# 147428   -0.194227
# 122429   -0.350638
# Name: Amount, Length: 226980, dtype: float64

# %%
X_test['Amount']
# Out:
# 104697   -0.127114
# 134356   -0.311733
# 42637    -0.168079
# 882      -0.336455
# 263275   -0.339387
#             ...
# 154645    0.029060
# 107561    0.184204
# 185406   -0.219978
# 59492     0.012896
# 263579   -0.313001
# Name: Amount, Length: 56746, dtype: float64

# %%
corr = df.corr(numeric_only=True)["Class"].sort_values()
plt.figure(figsize=(8,6))
corr.plot(kind="barh")
plt.title("Correlation of features with fraud class")
plt.show()

# %% [markdown]
# ##### Base model

# %% [markdown]
# ##### supervised learning

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import (accuracy_score, 
                             precision_score,
                             recall_score, 
                             f1_score, 
                             roc_auc_score)

# %%
model = LogisticRegression(random_state=42)

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(Y_test, y_pred))
print("Precision:", precision_score(Y_test, y_pred))
print("Recall   :", recall_score(Y_test, y_pred))
print("F1 Score :", f1_score(Y_test, y_pred))
print("ROC-AUC  :", roc_auc_score(Y_test, y_pred))
# Out:
# Accuracy: 0.9991541254009093
# Precision: 0.875
# Recall   : 0.5444444444444444
# F1 Score : 0.6712328767123288
# ROC-AUC  : 0.7721604458878533

# %%
model1 = LogisticRegression(class_weight="balanced", random_state=42)

# %%
def seq(modelx) -> None:
    modelx.fit(X_train, Y_train)
    y_pred = modelx.predict(X_test)

    print("Accuracy :", accuracy_score(Y_test, y_pred))
    print("Precision:", precision_score(Y_test, y_pred))
    print("Recall   :", recall_score(Y_test, y_pred))
    print("F1 Score :", f1_score(Y_test, y_pred))
    print("ROC-AUC  :", roc_auc_score(Y_test, y_pred))

# %%
seq(model)
# Out:
# Accuracy : 0.9991541254009093
# Precision: 0.875
# Recall   : 0.5444444444444444
# F1 Score : 0.6712328767123288
# ROC-AUC  : 0.7721604458878533

# %%
seq(model1)
# Out:
# Accuracy : 0.9775843231240968
# Precision: 0.05961251862891207
# Recall   : 0.8888888888888888
# F1 Score : 0.11173184357541899
# ROC-AUC  : 0.9333070538768081

# %%
#from the results obtained we can see the difference in when the class
#was balanced and when it was not so our job is to find a level plain ground for both

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(random_state=42)

# %%
rf1 = RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
rf_t = RandomForestClassifier(class_weight='balanced', n_estimators=100)

# %%
seq(rf)
# Out:
# Accuracy : 0.9995418179254926
# Precision: 0.9705882352941176
# Recall   : 0.7333333333333333
# F1 Score : 0.8354430379746836
# ROC-AUC  : 0.8666490162854185

# %%
seq(rf_t)
# Out:
# Accuracy : 0.9995418179254926
# Precision: 0.9571428571428572
# Recall   : 0.7444444444444445
# F1 Score : 0.8375
# ROC-AUC  : 0.8721957466503498

# %%
seq(rf1)
# Out:
# Accuracy : 0.9995594403129736
# Precision: 0.9577464788732394
# Recall   : 0.7555555555555555
# F1 Score : 0.84472049689441
# ROC-AUC  : 0.8777513022059055

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(
    random_state=42,
    eval_metric='logloss'
)

# %%
ratio = len(Y_train[Y_train==0]) / len(Y_train[Y_train==1])
ratio
# Out:
# 591.6370757180157

# %%
xgb1 = XGBClassifier(
    random_state=42,
    eval_metric='logloss',
    scale_pos_weight=ratio
)

# %%
seq(xgb)
# Out:
# Accuracy : 0.9994184612131252
# Precision: 0.9014084507042254
# Recall   : 0.7111111111111111
# F1 Score : 0.7950310559006211
# ROC-AUC  : 0.8554937792211867

# %%
y_pred = (xgb.predict_proba(X_test)[:,1] >= 0.4).astype(int)

# %%
def eval_met(y_pred, Y_test):
    print("Accuracy:", accuracy_score(y_pred, Y_test))
    print("Precision:", precision_score(y_pred, Y_test))
    print("Recall:", recall_score(y_pred, Y_test))
    print("f1_score:", f1_score(y_pred, Y_test))
    print("Roc_auc:", roc_auc_score(y_pred, Y_test))

# %%
eval_met(y_pred, Y_test)
# Out:
# Accuracy: 0.9993832164381631
# Precision: 0.7111111111111111
# Recall: 0.8767123287671232
# f1_score: 0.7852760736196319
# Roc_auc: 0.9381267782561288

# %%
seq(xgb1)
# Out:
# Accuracy : 0.9995241955380115
# Precision: 0.92
# Recall   : 0.7666666666666667
# F1 Score : 0.8363636363636363
# ROC-AUC  : 0.8832803821895886

# %%
prob = (xgb1.predict_proba(X_test)[:,1]>=0.5).astype(int)

# %%
#for xgboost predict proba of 0.5 is ok.

# %%
eval_met(prob, Y_test)
# Out:
# Accuracy: 0.9995241955380115
# Precision: 0.7666666666666667
# Recall: 0.92
# f1_score: 0.8363636363636363
# Roc_auc: 0.9598147200508196

# %% [markdown]
# ##### Hyperparameter tunning to choose the best model for this project.

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'class_weight': [None, 'balanced']
}

# %%
grid = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    scoring='f1',
    cv=5,
    n_jobs=-1,
    verbose=2
)

# %%
grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'class_weight': [None, 'balanced'],
#                          'max_depth': [10, 20, None],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              scoring='f1', verbose=2)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'class_weight': 'balanced', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# 0.8597877220898272

# %%
t = pd.read_csv("../data/model_data/y_test.csv")

# %%
t.squeeze()
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 56741    0
# 56742    0
# 56743    0
# 56744    0
# 56745    0
# Name: Class, Length: 56746, dtype: int64

# %%
best_rf = grid.best_estimator_

y_pred = best_rf.predict(X_test)

# %%
best_rf = grid.best_estimator_

# %%
seq(best_rf)
# Out:
# Accuracy : 0.9995241955380115
# Precision: 0.9315068493150684
# Recall   : 0.7555555555555555
# F1 Score : 0.8343558282208589
# ROC-AUC  : 0.8777336518246571

# %%
y_proba = (best_rf.predict_proba(X_test)[:,1]>=0.4).astype(int)

# %%
eval_met(y_proba, Y_test)
# Out:
# Accuracy: 0.9995418179254926
# Precision: 0.7777777777777778
# Recall: 0.9210526315789473
# f1_score: 0.8433734939759037
# Roc_auc: 0.9603498555812506

# %% [markdown]
# ##### unsupervised learning

# %%
from sklearn.ensemble import IsolationForest

# %%
iso = IsolationForest(
    contamination=df["Class"].mean(),
    random_state=42
)

# %%
iso.fit(X_train)
# Out:
# IsolationForest(contamination=np.float64(0.001667101358352777), random_state=42)

# %%
pred = iso.predict(X_test)

# %%
pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(56746,))

# %%
pred = [1 if x == -1 else 0 for x in pred]

# %%
eval_met(pred, Y_test)
# Out:
# Accuracy: 0.9974271314277658
# Precision: 0.2111111111111111
# Recall: 0.20212765957446807
# f1_score: 0.20652173913043478
# Roc_auc: 0.6004371970116922

# %%
iso1 = IsolationForest(
    n_estimators=300,
    contamination=0.0017,
    max_samples='auto',
    random_state=42
)

# %%
iso1.fit(X_train)
# Out:
# IsolationForest(contamination=0.0017, n_estimators=300, random_state=42)

# %%
pred1 = iso1.predict(X_test)

# %%
pred1 = [1 if x ==-1 else 0 for x in pred1 ]

# %%
eval_met(pred1, Y_test)
# Out:
# Accuracy: 0.9974447538152469
# Precision: 0.2111111111111111
# Recall: 0.20430107526881722
# f1_score: 0.20765027322404372
# Roc_auc: 0.6015239159197598

# %%
from sklearn.neighbors import LocalOutlierFactor
lof = LocalOutlierFactor(
    contamination=df['Class'].mean(),
    n_neighbors=20,
    novelty=True
                         )

# %%
lof.fit(X_train)
# Out:
# LocalOutlierFactor(contamination=np.float64(0.001667101358352777), novelty=True)

# %%
pred_f =  lof.predict(X_test)
# Out:
# c:\Users\USER\anaconda3\envs\test\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(

# %%
pred_f = [1 if x == -1 else 0 for x in pred_f]

# %%
eval_met(pred_f, Y_test)
# Out:
# Accuracy: 0.996863215028372
# Precision: 0.0
# Recall: 0.0
# f1_score: 0.0
# Roc_auc: 0.49920576088107593
